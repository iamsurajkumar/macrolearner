# %% [markdown]
# # How the fluctuations to the large firms drive the Macro Economy
#
# > An exploration of how the fluctuations to the large firms drive the Macro Economy using Deep Learning techniques.

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd


x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("Sine Wave")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
# Out:
# Text(0.5, 1.0, 'Sine Wave')
# Text(0.5, 0, 'X-axis')
# Text(0, 0.5, 'Y-axis')
